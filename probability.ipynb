# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("kerala.csv")
df
# Out:
#     SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG  \
# 0        KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5
# 1        KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8
# 2        KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2
# 3        KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8
# 4        KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6
# ..          ...   ...   ...   ...   ...    ...    ...     ...     ...     ...
# 113      KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9
# 114      KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2
# 115      KERALA  2016   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5
# 116     KERALA   2017   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8
# 117      KERALA  2018  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9
#
# ...

# %%
df["YEAR"].unique()
# Out:
# array([1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911,
#        1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922,
#        1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933,
#        1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944,
#        1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955,
#        1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966,
#        1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977,
#        1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,
#        1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], dtype=int64)

# %%
df.describe()
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   118.000000  118.000000  118.000000  118.000000  118.000000
# mean   1959.500000   12.218644   15.633898   36.670339  110.330508
# std      34.207699   15.473766   16.406290   30.063862   44.633452
# min    1901.000000    0.000000    0.000000    0.100000   13.100000
# 25%    1930.250000    2.175000    4.700000   18.100000   74.350000
# 50%    1959.500000    5.800000    8.350000   28.400000  110.400000
# 75%    1988.750000   18.175000   21.400000   49.825000  136.450000
# max    2018.000000   83.500000   79.000000  217.200000  238.000000
#
#               MAY          JUN          JUL          AUG         SEP  \
# count  118.000000   118.000000   118.000000   118.000000  118.000000
# mean   228.644915   651.617797   698.220339   430.369492  246.207627
# std    147.548778   186.181363   228.988966   181.980463  121.901131
# min     53.400000   196.800000   167.500000   178.600000   41.300000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBDIVISION       118 non-null    object
#  1   YEAR              118 non-null    int64
#  2   JAN               118 non-null    float64
#  3   FEB               118 non-null    float64
#  4   MAR               118 non-null    float64
#  5   APR               118 non-null    float64
#  6   MAY               118 non-null    float64
#  7   JUN               118 non-null    float64
#  8   JUL               118 non-null    float64
#  9   AUG               118 non-null    float64
#  10  SEP               118 non-null    float64
#  11  OCT               118 non-null    float64
#  12  NOV               118 non-null    float64
#  13  DEC               118 non-null    float64
#  14   ANNUAL RAINFALL  118 non-null    float64
#  15  FLOODS            118 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', ' ANNUAL RAINFALL', 'FLOODS'],
#       dtype='object')

# %%
df["FLOODS"].value_counts()
# Out:
# FLOODS
# YES    60
# NO     58
# Name: count, dtype: int64

# %%
df["FLOODS"]=df["FLOODS"].map({"YES":1,"NO":0})

# %%
df.head()
# Out:
#   SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG  \
# 0      KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5
# 1      KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8
# 2      KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2
# 3      KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8
# 4      KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6
#
#      SEP    OCT    NOV    DEC   ANNUAL RAINFALL  FLOODS
# 0  197.7  266.9  350.8   48.4            3248.6       1
# 1  491.6  358.4  158.3  121.5            3326.6       1
# 2  341.8  354.1  157.0   59.0            3271.2       1
# 3  222.7  328.1   33.9    3.3            3129.7       1
# 4  217.2  383.5   74.4    0.2            2741.6       0

# %%
df["data_of_june"]=(df["JUN"]>=500).astype("int")
df["data_of_june"]
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 113    0
# 114    1
# 115    1
# 116    0
# 117    1
# Name: data_of_june, Length: 118, dtype: int32

# %%
df["data_of_jul"]=(df["JUL"]>=500).astype("int")
df["data_of_jul"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 113    1
# 114    0
# 115    0
# 116    0
# 117    1
# Name: data_of_jul, Length: 118, dtype: int32

# %%
df.head()
# Out:
#   SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG  \
# 0      KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5
# 1      KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8
# 2      KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2
# 3      KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8
# 4      KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6
#
#      SEP    OCT    NOV    DEC   ANNUAL RAINFALL  FLOODS  data_of_june  \
# 0  197.7  266.9  350.8   48.4            3248.6       1             1
# 1  491.6  358.4  158.3  121.5            3326.6       1             0
# 2  341.8  354.1  157.0   59.0            3271.2       1             1
# 3  222.7  328.1   33.9    3.3            3129.7       1             1
# 4  217.2  383.5   74.4    0.2            2741.6       0             1
#
#    data_of_jul
# 0            1
# 1            1
# 2            1
# 3            1
# ...

# %%
small_data=df.loc[:,["YEAR","data_of_june","data_of_jul","FLOODS"]]
small_data.head()
# Out:
#    YEAR  data_of_june  data_of_jul  FLOODS
# 0  1901             1            1       1
# 1  1902             0            1       1
# 2  1903             1            1       1
# 3  1904             1            1       1
# 4  1905             1            1       0

# %%
#pd.crosstab()
pd.crosstab(small_data["FLOODS"],small_data["data_of_jul"])
# Out:
# data_of_jul   0   1
# FLOODS
# 0            19  39
# 1             3  57

# %%
jul=small_data["data_of_jul"].value_counts().sort_values().plot(kind="bar")
jul
# Out:
# <Axes: xlabel='data_of_jul'>

# %%
sns.countplot(x="data_of_jul",hue="FLOODS",data=small_data)
# Out:
# <Axes: xlabel='data_of_jul', ylabel='count'>

# %%
#plt.pie(jul,labels=jul.index,autopct="%.2f",explode=(0,0.1))
#plt.show()

# %%
pd.crosstab(small_data["FLOODS"],small_data["data_of_june"])
# Out:
# data_of_june   0   1
# FLOODS
# 0             19  39
# 1              6  54

# %%
df["data_of_aug"]=(df["AUG"]>=300).astype("int")
df["data_of_aug"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 113    1
# 114    0
# 115    1
# 116    1
# 117    1
# Name: data_of_aug, Length: 118, dtype: int32

# %%
df["data_of_sept"]=(df["SEP"]>=300).astype("int")
df["data_of_sept"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 113    0
# 114    0
# 115    0
# 116    0
# 117    1
# Name: data_of_sept, Length: 118, dtype: int32

# %%
small_data1=df.loc[:,["YEAR","data_of_aug","data_of_sept","FLOODS"]]
small_data1.head()
# Out:
#    YEAR  data_of_aug  data_of_sept  FLOODS
# 0  1901            1             0       1
# 1  1902            1             1       1
# 2  1903            1             1       1
# 3  1904            1             0       1
# 4  1905            0             0       0

# %%
pd.crosstab(small_data1["FLOODS"],small_data1["data_of_aug"])
# Out:
# data_of_aug   0   1
# FLOODS
# 0            17  41
# 1             9  51

# %%
aug=small_data1["data_of_aug"].value_counts().sort_values().plot(kind="barh")
aug
# Out:
# <Axes: ylabel='data_of_aug'>

# %%
sept=small_data1["data_of_aug"].value_counts().sort_values().plot(kind="bar")
sept
# Out:
# <Axes: xlabel='data_of_aug'>

# %%
sns.countplot(x="data_of_aug",hue="FLOODS",data=small_data1)
# Out:
# <Axes: xlabel='data_of_aug', ylabel='count'>
