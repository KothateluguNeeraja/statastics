# %% [markdown]
# # Categorical data

# %%
#categorical(Quantitative)
#the data which are in string type we called as categorical data
#we can't measure it and we can't perform methomatical calculations
#no statatical analysis

# %%
import pandas as pd
import numpy as np

# %%
sample=pd.read_csv("SampleSuperstore.csv")
sample
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df=sample.head()

# %%
df
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     5 non-null      object
#  1   Segment       5 non-null      object
#  2   Country       5 non-null      object
#  3   City          5 non-null      object
#  4   State         5 non-null      object
#  5   Postal Code   5 non-null      int64
#  6   Region        5 non-null      object
#  7   Category      5 non-null      object
#  8   Sub-Category  5 non-null      object
#  9   Sales         5 non-null      float64
#  10  Quantity      5 non-null      int64
#  11  Discount      5 non-null      float64
#  12  Profit        5 non-null      float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 652.0+ bytes

# %%
df.describe()
# Out:
#         Postal Code       Sales  Quantity  Discount      Profit
# count      5.000000    5.000000   5.00000  5.000000    5.000000
# mean   48299.600000  397.693100   2.80000  0.130000  -22.429520
# std    23771.741297  427.559626   1.30384  0.198746  220.354194
# min    33311.000000   14.620000   2.00000  0.000000 -383.031000
# 25%    33311.000000   22.368000   2.00000  0.000000    2.516400
# 50%    42420.000000  261.960000   2.00000  0.000000    6.871400
# 75%    42420.000000  731.940000   3.00000  0.200000   41.913600
# max    90036.000000  957.577500   5.00000  0.450000  219.582000

# %%
df["Ship Mode"].unique()
# Out:
# array(['Second Class', 'Standard Class'], dtype=object)

# %%
netflix=pd.read_csv("netflix_titles.csv")
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df1=netflix.head()

# %%
df1.isnull().any()
# Out:
# show_id         False
# type            False
# title           False
# director         True
# cast             True
# country          True
# date_added      False
# release_year    False
# rating          False
# duration        False
# listed_in       False
# description     False
# dtype: bool

# %%
df1.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        3
# cast            2
# country         2
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5 non-null      object
#  1   type          5 non-null      object
#  2   title         5 non-null      object
#  3   director      2 non-null      object
#  4   cast          3 non-null      object
#  5   country       3 non-null      object
#  6   date_added    5 non-null      object
#  7   release_year  5 non-null      int64
#  8   rating        5 non-null      object
#  9   duration      5 non-null      object
#  10  listed_in     5 non-null      object
#  11  description   5 non-null      object
# dtypes: int64(1), object(11)
# memory usage: 612.0+ bytes

# %% [markdown]
# # Numerical data

# %%
# The data in float type
#we can do statastical analysis ,we can measure and we can mathematical calculations
#mean(),mode(),median()

# %%
df1['director'].fillna(df1['director'].mode()[0],inplace=True)
# Out:
# C:\Users\kotha\AppData\Local\Temp\ipykernel_16788\1577503828.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['director'].fillna(df1['director'].mode()[0],inplace=True)
# C:\Users\kotha\AppData\Local\Temp\ipykernel_16788\1577503828.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df1["director"].isnull().sum()
# Out:
# 0

# %%
df1['cast'].fillna(df1['cast'].mode()[0],inplace=True)
# Out:
# C:\Users\kotha\AppData\Local\Temp\ipykernel_16788\1260236558.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['cast'].fillna(df1['cast'].mode()[0],inplace=True)
# C:\Users\kotha\AppData\Local\Temp\ipykernel_16788\1260236558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df1["cast"].isnull().sum()
# Out:
# 0

# %%
df1['country'].fillna(df1['country'].mode()[0],inplace=True)
# Out:
# C:\Users\kotha\AppData\Local\Temp\ipykernel_16788\609724442.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['country'].fillna(df1['country'].mode()[0],inplace=True)
# C:\Users\kotha\AppData\Local\Temp\ipykernel_16788\609724442.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df1['country'].isnull().sum()
# Out:
# 0

# %%
df1.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water  Julien Leclercq
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  Julien Leclercq
# 4      s5  TV Show           Kota Factory  Julien Leclercq
#
#                                                 cast        country  \
# 0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...          India
# 3  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...          India
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # Measure of dispersion

# %%
#it is used with mean,median,mode.

# %%
#Range
#Interquartile Range:IQR=Q3-Q1
#variance
#Standard deviation

# %%
import numpy as np
dt=[1,2,3,4,5,6,7,8,9]
print(np.ptp(dt))
print(np.var(dt))
# Out:
# 8
# 6.666666666666667

# %%
df2=pd.read_csv("HRDataset_v14.csv")
df2
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
df2.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df3=df2[["EmpID","DeptID","Department",'Salary']]
df3.head()
# Out:
#    EmpID  DeptID         Department  Salary
# 0  10026       5  Production          62506
# 1  10084       3              IT/IS  104437
# 2  10196       5  Production          64955
# 3  10088       5  Production          64991
# 4  10069       5  Production          50825

# %%
df2["Department"].value_counts()
# Out:
# Department
# Production              209
# IT/IS                    50
# Sales                    31
# Software Engineering     11
# Admin Offices             9
# Executive Office          1
# Name: count, dtype: int64

# %%
df2.groupby(["Department"])["Salary"].mean()
# Out:
# Department
# Admin Offices            71791.888889
# Executive Office        250000.000000
# IT/IS                    97064.640000
# Production               59953.545455
# Sales                    69061.258065
# Software Engineering     94989.454545
# Name: Salary, dtype: float64

# %%
mean=df2.groupby("Department").Salary.mean().reset_index()
mean
# Out:
#              Department         Salary
# 0         Admin Offices   71791.888889
# 1      Executive Office  250000.000000
# 2                 IT/IS   97064.640000
# 3     Production          59953.545455
# 4                 Sales   69061.258065
# 5  Software Engineering   94989.454545

# %%
display(df2["Salary"].mode())
# Out:
# 0    57815
# 1    61242
# 2    63025
# Name: Salary, dtype: int64

# %%
display(mean["Salary"].var())
# Out:
# 5116833840.207844

# %%
median=df2.groupby("Department").Salary.median().reset_index()
display(median)
# Out:
#              Department    Salary
# 0         Admin Offices   63003.0
# 1      Executive Office  250000.0
# 2                 IT/IS   92328.5
# 3     Production          59472.0
# 4                 Sales   65310.0
# 5  Software Engineering   95660.0

# %%
display(median["Salary"].std())
# Out:
# 73050.21312523098

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df2.groupby("Department")["Salary"].mean().sort_values().plot.barh(figsize=(10,5))
plt.xlabel("Salary")
plt.ylabel("Department")
plt.title("salary on dept")
plt.show()

# %%
df2.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')
